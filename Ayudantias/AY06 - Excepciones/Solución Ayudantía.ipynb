# %% [markdown]
# ## Ayudantía Excepciones
#
# El equipo de Tube-You creó un módulo library.py para analizar los datos de sus videos. Sin embargo,
# dicho código no identifica adecuadamente los errores de formato (o de consistencia) que pueden aparecer. Tu
# deber será tomar la librerı́a fallida, identificar los errores pertinentes, y levantar las excepciones según sea
# necesario.
#
# Para esta parte trabajarás en el archivo library.py, donde podrás encontrar las funciones a revisar.
# **ESTÁ PROHIBIDO BORRAR CUALQUIER LÍNEA DE CÓDIGO DE ESTE ARCHIVO**; es
# decir, sólo podrás agregar las lı́neas necesarias. Además, tampoco podrás utilizar try o except en el archivo
# library.py, pues el manejo de excepciones lo haremos después en otro módulo.
#
# ### `tiempo_trending(publish_date: str, trending_date: str) -> int`
#
# Esta función retorna un número entero que indica la cantidad de dı́as desde que el video fue publicado, hasta que se volvió trending. Para esta función, debemos revisar el argumento publish date. La fecha publish date debe venir con el formato %y. %d. %m, en el que el año, dı́a y mes aparecen con dos dı́gitos y separados con puntos. Por lo tanto, se debe levantar una excepción personalizada creada por ti cuando la fecha no esté en el formato correcto.

# %%
import datetime

def tiempo_trending(publish_date, trending_date):

    if ((publish_date[2] != "." or publish_date[5] != ".") or \
    (trending_date[2] != "." or trending_date[5] != ".")) or \
    (any(c.isalpha() for c in publish_date)
    or any(c.isalpha() for c in trending_date)):
        raise WrongFormat(publish_date, trending_date)

    publish_d = datetime.datetime.strptime(publish_date, "%y.%d.%m")
    trending_d = datetime.datetime.strptime(trending_date, "%y.%d.%m")
    days = (trending_d - publish_d).days

    return days

# %% [markdown]
# ## `like_dislike_ratio(likes: str, dislikes: str) -> float`
#
# Esta función retorna el cociente entre los `likes` y `dislikes` del video.
# En esta función debemos revisar el formato de likes. Si el argumento likes no está compuesto por solo
# números, entonces se debe levantar una excepción del tipo adecuado. Como se espera obtener el resultado de una división, además debes asegurarte de que una excepción de tipo `ZeroDivisionError` se levante al dividir por cero.

# %%
def like_dislike_ratio(likes, dislikes):

    if not likes.isdigit() or not dislikes.isdigit():
        raise ValueError("Likes y dislikes deben ser solo numeros")

    if dislikes == "0":
        raise ZeroDivisionError("Division por cero")

    return int(likes) / int(dislikes)

# %% [markdown]
# ## `info_video(title: str, views: str, likes: str, dislikes: str, tags: str)`
#
# Esta función imprime un resumen de las estadı́sticas del video. En este caso, debes crear ***dos custom exceptions***. La primera excepción se levantará, cuando algún video posea mas likes que views, es decir, cuando `likes > views`. La segunda, se levantará en caso de que tags sea un string de largo `0` o `None`.

# %%
def info_video(title, views, likes, dislikes, tags):

    if not likes.isdigit() or not views.isdigit():
        raise ValueError("Likes y views deben ser solo numeros")

    if int(likes) > int(views):
        raise LikesOverViews(likes, views)
    
    if len(tags) == 0 or type(tags) == None:
        raise TagsType(tags)

    print("El video {0} ha tenido {1} views, con {2} likes y {3} dislikes"
          .format(title, views, likes, dislikes))

# %% [markdown]
# ## Haz tus excepciones acá

# %%
#Excepciones personalizadas

class WrongFormat(Exception):

    def __init__(self, publish_date, trending_date):
        super().__init__("Error: Fecha está en el formato incorrecto")
        self.publish_date = publish_date
        self.trending_date = trending_date


class LikesOverViews(Exception):

    def __init__(self, likes, views):
        super().__init__("Error: Los likes no pueden superar los views")
        self.likes = likes
        self.views = views
        

class TagsType(Exception):

    def __init__(self, tags):
        super().__init__("Error: Tags no pueden ser vacíos")
        self.tags = tags

# %% [markdown]
# ## Prueba tu código acá

# %%
class Video:
    def __init__(self, trending_date, title, publish_date, tags, views, likes,
                 dislikes):
        self.title = title
        self.trending_date = trending_date
        self.publish_date = publish_date
        self.tags = tags
        self.views = views
        self.likes = likes
        self.dislikes = dislikes

    def __str__(self):
        return self.title

    
def file_reading():
    with open("data_errores.txt", "r", encoding="utf-8") as file:
        lines = file.readlines()[1:]
        video_list = []

        for line in lines:
            data = line.strip().split(",")
            video_list.append(Video(*data))
    return video_list

videos = file_reading()

# A partir de este punto, el estudiante debe manejar los errores
with open("excepciones.txt", "w") as file:
    for video in videos:
        try:
            days = tiempo_trending(
                video.publish_date, video.trending_date)
            print("El video {} estuvo trending {} dia(s) despues de publicado"
                  .format(video.title, days))
        except WrongFormat as err:
            file.write("El video {} levanto la siguiente excepcion: {}\n". format(
                video.title, err))
            
        try:
            ratio = like_dislike_ratio(video.likes, video.dislikes)
            print("El video {} tiene aproximadamente {} likes por dislike"
                  .format(video.title, ratio))
        except ValueError as err:
            file.write("El video {} levanto la siguiente excepcion: {}\n". format(
                video.title, err))
        except ZeroDivisionError as err:
            file.write("El video {} levanto la siguiente excepcion.: {}\n". format(
                video.title, err))

        try:
            info_video(video.title, video.views, video.likes,
                           video.dislikes, video.tags)
            print()
        except ValueError as err:
            file.write("El video {} levanto la siguiente excepcion: {}\n". format(
                video.title, err))
        except LikesOverViews as err:
            file.write("El video {} levanto la siguiente excepcion: {}\n". format(
                video.title, err))
        except TagsType as err:
            file.write("El video {} levanto la siguiente excepcion: {}\n". format(
                video.title, err))
# Out:
# El video Black Panther New Scene - SNL estuvo trending 1 dia(s) despues de publicado
# El video TIED UP CHALLENGE!! estuvo trending 1 dia(s) despues de publicado
# El video TIED UP CHALLENGE!! tiene aproximadamente 66191.0 likes por dislike
# El video TIED UP CHALLENGE!! ha tenido 1498364 views, con 132382 likes y 2 dislikes
#
# El video Getting Turned On - Man Vs House Ep.#7 estuvo trending 1 dia(s) despues de publicado
# El video Getting Turned On - Man Vs House Ep.#7 tiene aproximadamente 93.60695187165776 likes por dislike
# El video Getting Turned On - Man Vs House Ep.#7 ha tenido 604944 views, con 35009 likes y 374 dislikes
#
# El video Falcon Heavy & Starman estuvo trending 1 dia(s) despues de publicado
# El video Falcon Heavy & Starman tiene aproximadamente 92.89295272078502 likes por dislike
# El video The FASTEST Grand Mac Meal Ever Eaten (under 1 Minute!!) estuvo trending 2 dia(s) despues de publicado
# El video The FASTEST Grand Mac Meal Ever Eaten (under 1 Minute!!) tiene aproximadamente 14.938225662399523 likes por dislike
# El video The FASTEST Grand Mac Meal Ever Eaten (under 1 Minute!!) ha tenido 3151874 views, con 100355 likes y 6718 dislikes
#
# El video The FASTEST Grand Mac Meal Ever Eaten (under 1 Minute!!) estuvo trending 1 dia(s) despues de publicado
# El video Super Smash Bros - Trailer Analysis estuvo trending 1 dia(s) despues de publicado
# El video Super Smash Bros - Trailer Analysis tiene aproximadamente 38.0419595314164 likes por dislike
# El video Super Smash Bros - Trailer Analysis ha tenido 2656683 views, con 178607 likes y 4695 dislikes
#
# El video The Historic Disappearance of Louis Le Prince estuvo trending 2 dia(s) despues de publicado
# El video The Historic Disappearance of Louis Le Prince tiene aproximadamente 61.591928251121075 likes por dislike
# El video I TRIED FOLLOWING A SIMPLY NAILOGICAL MAKEUP TUTORIAL... WOW! estuvo trending 1 dia(s) despues de publicado
# El video I TRIED FOLLOWING A SIMPLY NAILOGICAL MAKEUP TUTORIAL... WOW! ha tenido 1071804 views, con 96363 likes y 0 dislikes
#
# El video Pen Circle Traps Ant (But How?) tiene aproximadamente 10.085647471499561 likes por dislike
# El video Pen Circle Traps Ant (But How?) ha tenido 1523626 views, con 34503 likes y 3421 dislikes
#
# El video [OFFICIAL VIDEO] New Rules x Are You That Somebody? - Pentatonix estuvo trending 1 dia(s) despues de publicado
# El video [OFFICIAL VIDEO] New Rules x Are You That Somebody? - Pentatonix tiene aproximadamente 53.47234042553192 likes por dislike
# El video [OFFICIAL VIDEO] New Rules x Are You That Somebody? - Pentatonix ha tenido 929912 views, con 87962 likes y 1645 dislikes
#
# El video The Grinch - Official Trailer (HD) estuvo trending 2 dia(s) despues de publicado
# El video The Grinch - Official Trailer (HD) tiene aproximadamente 3.5035856573705177 likes por dislike
# El video The Grinch - Official Trailer (HD) ha tenido 3221044 views, con 48367 likes y 13805 dislikes
#
# El video Nintendo Direct 3.8.2018 estuvo trending 2 dia(s) despues de publicado
# El video Nintendo Direct 3.8.2018 tiene aproximadamente 27.56343612334802 likes por dislike
# El video Nintendo Direct 3.8.2018 ha tenido 2075113 views, con 62569 likes y 2270 dislikes
#
# El video Official Call of Duty®: Black Ops 4 Teaser estuvo trending 2 dia(s) despues de publicado
# El video Official Call of Duty®: Black Ops 4 Teaser tiene aproximadamente 8.320253164556963 likes por dislike
# El video Official Call of Duty®: Black Ops 4 Teaser ha tenido 2851930 views, con 138033 likes y 16590 dislikes
#
# El video Mindy Kaling Liked Stephen's Baby Gift... But Not As Much As Oprah's estuvo trending 1 dia(s) despues de publicado
# El video Mindy Kaling Liked Stephen's Baby Gift... But Not As Much As Oprah's ha tenido 361056 views, con 3493 likes y 0 dislikes
#
# El video Nintendo Direct 3.8.2018 tiene aproximadamente 46.80609756097561 likes por dislike
# El video Nintendo Direct 3.8.2018 ha tenido 904177 views, con 38381 likes y 820 dislikes
#
# El video Camila Cabello - Never Be the Same estuvo trending 1 dia(s) despues de publicado
# El video Camila Cabello - Never Be the Same tiene aproximadamente 44.65931263858093 likes por dislike
# El video Camila Cabello - Never Be the Same ha tenido 3008740 views, con 402827 likes y 9020 dislikes
#
# El video Official Call of Duty®: Black Ops 4 Teaser estuvo trending 1 dia(s) despues de publicado
# El video Official Call of Duty®: Black Ops 4 Teaser tiene aproximadamente 15.319104041551697 likes por dislike
# El video The Grinch - Official Trailer (HD) estuvo trending 1 dia(s) despues de publicado
# El video Ew! with John Cena estuvo trending 1 dia(s) despues de publicado
# El video Ew! with John Cena tiene aproximadamente 29.144756277695716 likes por dislike
# El video Ew! with John Cena ha tenido 1384556 views, con 39462 likes y 1354 dislikes
#
# El video Blind Fast Food Sub Sandwich Taste Test estuvo trending 1 dia(s) despues de publicado
# El video Blind Fast Food Sub Sandwich Taste Test tiene aproximadamente 41.32919254658385 likes por dislike
# El video Blind Fast Food Sub Sandwich Taste Test ha tenido 1196319 views, con 26616 likes y 644 dislikes
#
# El video ELDERS REACT AND TRY McDONALD’S SZECHUAN SAUCE (Rick and Morty) estuvo trending 1 dia(s) despues de publicado
# El video ELDERS REACT AND TRY McDONALD’S SZECHUAN SAUCE (Rick and Morty) ha tenido 346573 views, con 11402 likes y 0 dislikes
#
# El video Christopher Robin Official Teaser Trailer estuvo trending 2 dia(s) despues de publicado
# El video Christopher Robin Official Teaser Trailer tiene aproximadamente 27.925925925925927 likes por dislike
# El video Christopher Robin Official Teaser Trailer ha tenido 4316022 views, con 108576 likes y 3888 dislikes
#
# El video Kristin Gets A Desk Makeover • Ladylike tiene aproximadamente 85.18013856812934 likes por dislike
# El video Kristin Gets A Desk Makeover • Ladylike ha tenido 699447 views, con 36883 likes y 433 dislikes
#
# El video Arie Luyendyk & Lauren Burnham the Morning After The Bachelor Finale estuvo trending 1 dia(s) despues de publicado
# El video Arie Luyendyk & Lauren Burnham the Morning After The Bachelor Finale tiene aproximadamente 3.006802721088435 likes por dislike
# El video Christopher Robin Official Teaser Trailer estuvo trending 1 dia(s) despues de publicado
# El video Christopher Robin Official Teaser Trailer tiene aproximadamente 40.54590395480226 likes por dislike
# El video Christopher Robin Official Teaser Trailer ha tenido 1870245 views, con 57413 likes y 1416 dislikes
#
# El video Honest Trailers - Thor: Ragnarok estuvo trending 1 dia(s) despues de publicado
# El video Honest Trailers - Thor: Ragnarok tiene aproximadamente 49.8923988153998 likes por dislike
# El video Honest Trailers - Thor: Ragnarok ha tenido 1178642 views, con 50541 likes y 1013 dislikes
#
# El video World's Longest LEGO Walk | Dude Perfect tiene aproximadamente 24.74371128807989 likes por dislike
# El video World's Longest LEGO Walk | Dude Perfect ha tenido 11887211 views, con 391495 likes y 15822 dislikes
#
# El video Kevin Hart On What The Fit & Sumo Wrestling With Conan  - CONAN on TBS estuvo trending 1 dia(s) despues de publicado
# El video Lost in Space | Official Trailer [HD] | Netflix estuvo trending 1 dia(s) despues de publicado
# El video Lost in Space | Official Trailer [HD] | Netflix tiene aproximadamente 35.38389513108614 likes por dislike
# El video Lost in Space | Official Trailer [HD] | Netflix ha tenido 1064893 views, con 18895 likes y 534 dislikes
#
# El video World's Longest LEGO Walk | Dude Perfect estuvo trending 1 dia(s) despues de publicado
# El video World's Longest LEGO Walk | Dude Perfect tiene aproximadamente 31.62224827406539 likes por dislike
# El video World's Longest LEGO Walk | Dude Perfect ha tenido 4852889 views, con 242764 likes y 7677 dislikes
#
# El video Mary Poppins Returns Official Teaser Trailer estuvo trending 1 dia(s) despues de publicado
# El video Mary Poppins Returns Official Teaser Trailer tiene aproximadamente 15.466344864574953 likes por dislike
# El video Mary Poppins Returns Official Teaser Trailer ha tenido 3141764 views, con 57674 likes y 3729 dislikes
#
# El video Girl Fits Into Fish Tank ft. Sofie Dossi tiene aproximadamente 78.31654676258992 likes por dislike
# El video Watch Jordan Peele's Oscar 2018 Acceptance Speech for Best Original Screenplay estuvo trending 1 dia(s) despues de publicado
# El video Watch Jordan Peele's Oscar 2018 Acceptance Speech for Best Original Screenplay tiene aproximadamente 19.969 likes por dislike
# El video Watch Jordan Peele's Oscar 2018 Acceptance Speech for Best Original Screenplay ha tenido 1076574 views, con 19969 likes y 1000 dislikes
#
# El video A Thirsty Sidewalk tiene aproximadamente 17.89670896114195 likes por dislike
